# %% [markdown]
# # Lecture 2: NLTK Continued and Word Frequencies
#
# - Semantics - meanings
# - Syntax - sentence structures
#
# ## What is a word?
#
# - Token - instance of a type
# - Types - unique, abstract form of tokens
# - Stem - truncated word
# - Lemma - dictionary form of a word, unconjugated

# %%
"Jon has an apple!".split()
# Out:
# ['Jon', 'has', 'an', 'apple!']

# %% [markdown]
# "The the the the the that's all folks!"
#  - 8 tokens, sometimes 10
#  - 4 types, sometimes 6

# %%
import nltk

# %%
nltk.__version__
# Out:
# '3.6.5'

# %%
nltk.download('book')
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /home/jon/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package brown to /home/jon/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package chat80 to /home/jon/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package cmudict to /home/jon/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /home/jon/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /home/jon/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# ...

# %%
dir(nltk)
# Out:
# ['ARLSTem',
#  'ARLSTem2',
#  'AbstractLazySequence',
#  'AffixTagger',
#  'AlignedSent',
#  'Alignment',
#  'AnnotationTask',
#  'ApplicationExpression',
#  'Assignment',
#  'BigramAssocMeasures',
#  'BigramCollocationFinder',
#  'BigramTagger',
#  'BinaryMaxentFeatureEncoding',
#  'BlanklineTokenizer',
#  'BllipParser',
#  'BottomUpChartParser',
#  'BottomUpLeftCornerChartParser',
#  'BottomUpProbabilisticChartParser',
#  'Boxer',
#  'BrillTagger',
#  'BrillTaggerTrainer',
#  'CFG',
#  'CRFTagger',
#  'CfgReadingCommand',
#  'ChartParser',
#  'ChunkParserI',
#  'ChunkScore',
#  'Cistem',
#  'ClassifierBasedPOSTagger',
#  'ClassifierBasedTagger',
#  'ClassifierI',
#  'ConcordanceIndex',
#  'ConditionalExponentialClassifier',
#  'ConditionalFreqDist',
#  'ConditionalProbDist',
#  'ConditionalProbDistI',
#  'ConfusionMatrix',
#  'ContextIndex',
#  'ContextTagger',
#  'ContingencyMeasures',
#  'CoreNLPDependencyParser',
#  'CoreNLPParser',
#  'Counter',
#  'CrossValidationProbDist',
# ...

# %%
#porky_words # snake_case
#porkyWords # camelCase 
porky_words = "The the the the the the that's all folks!"

# %%
nltk.tokenize.word_tokenize(porky_words)
# Out:
# ['The', 'the', 'the', 'the', 'the', 'the', 'that', "'s", 'all', 'folks', '!']

# %%
list(nltk.tokenize.simple.regexp_span_tokenize(porky_words, r'\s'))
# Out:
# [(0, 3),
#  (4, 7),
#  (8, 11),
#  (12, 15),
#  (16, 19),
#  (20, 23),
#  (24, 30),
#  (31, 34),
#  (35, 41)]

# %%
help(nltk.tokenize.word_tokenize)
# Out:
# Help on function word_tokenize in module nltk.tokenize:
#
# word_tokenize(text, language='english', preserve_line=False)
#     Return a tokenized copy of *text*,
#     using NLTK's recommended word tokenizer
#     (currently an improved :class:`.TreebankWordTokenizer`
#     along with :class:`.PunktSentenceTokenizer`
#     for the specified language).
#
#     :param text: text to split into words
#     :type text: str
#     :param language: the model name in the Punkt corpus
#     :type language: str
#     :param preserve_line: A flag to decide whether to sentence tokenize the text or not.
#     :type preserve_line: bool

# %% [markdown]
# ## Stemmers

# %%
stemmer = nltk.stem.lancaster.LancasterStemmer()

# %%
stemmer.stem('photography')
# Out:
# 'photograph'

# %%
stemmer.stem('photographer')
# Out:
# 'photograph'

# %%
stemmer.stem('best')
# Out:
# 'best'

# %% [markdown]
# ## Lemmatizers

# %%
lemmatizer = nltk.stem.WordNetLemmatizer()

# %%
lemmatizer.lemmatize('photographer')
# Out:
# 'photographer'

# %%
lemmatizer.lemmatize('ran')
# Out:
# 'ran'

# %%
lemmatizer.lemmatize('biggest')
# Out:
# 'biggest'

# %%
lemmatizer.lemmatize('went')
# Out:
# 'went'

# %%
help(nltk.stem.WordNetLemmatizer)
# Out:
# Help on class WordNetLemmatizer in module nltk.stem.wordnet:
#
# class WordNetLemmatizer(builtins.object)
#  |  WordNet Lemmatizer
#  |
#  |  Lemmatize using WordNet's built-in morphy function.
#  |  Returns the input word unchanged if it cannot be found in WordNet.
#  |
#  |      >>> from nltk.stem import WordNetLemmatizer
#  |      >>> wnl = WordNetLemmatizer()
#  |      >>> print(wnl.lemmatize('dogs'))
#  |      dog
#  |      >>> print(wnl.lemmatize('churches'))
#  |      church
#  |      >>> print(wnl.lemmatize('aardwolves'))
#  |      aardwolf
#  |      >>> print(wnl.lemmatize('abaci'))
#  |      abacus
#  |      >>> print(wnl.lemmatize('hardrock'))
#  |      hardrock
#  |
#  |  Methods defined here:
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  lemmatize(self, word: str, pos: str = 'n') -> str
#  |      Lemmatize `word` using WordNet's built-in morphy function.
#  |      Returns the input word unchanged if it cannot be found in WordNet.
#  |
# ...

# %%
porky_words = porky_words.lower()

# %%
porky_words
# Out:
# "the the the the the the that's all folks!"

# %%
help(nltk.FreqDist())
# Out:
# Help on FreqDist in module nltk.probability object:
#
# class FreqDist(collections.Counter)
#  |  FreqDist(samples=None)
#  |
#  |  A frequency distribution for the outcomes of an experiment.  A
#  |  frequency distribution records the number of times each outcome of
#  |  an experiment has occurred.  For example, a frequency distribution
#  |  could be used to record the frequency of each word type in a
#  |  document.  Formally, a frequency distribution can be defined as a
#  |  function mapping from each sample to the number of times that
#  |  sample occurred as an outcome.
#  |
#  |  Frequency distributions are generally constructed by running a
#  |  number of experiments, and incrementing the count for a sample
#  |  every time it is an outcome of an experiment.  For example, the
#  |  following code will produce a frequency distribution that encodes
#  |  how often each word occurs in a text:
#  |
#  |      >>> from nltk.tokenize import word_tokenize
# ...

# %% [markdown]
# porky_tokens = nltk.word_tokenize(porky_words)

# %%
freq_dist = nltk.FreqDist(porky_tokens)

# %%
freq_dist
# Out:
# FreqDist({'the': 6, 'that': 1, "'s": 1, 'all': 1, 'folks': 1, '!': 1})

# %%
lemmatizer.lemmatize("'s")
# Out:
# "'s"

# %% [markdown]
#  - Hapax legomena :: tokens that only occur once

# %%
freq_dist.hapaxes()
# Out:
# ['that', "'s", 'all', 'folks', '!']

# %%
freq_dist.plot()
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
type(text6)
# Out:
# nltk.text.Text

# %%
len(text6)
# Out:
# 16967

# %%
import pandas as pd

# %%
all_texts = [text1, text2, text3, text4, text5, text6, text7, text8, text9]
lengths = {text.name: len(text) for text in all_texts}

# %%
pd.Series([len(text) for text in 
           [text1, text2, text3, text4, 
            text5, text6, text7, text8, text9]]).plot()
# Out:
# <AxesSubplot:>

# %%
pd.Series(lengths).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## N-grams
#
# Groups of words.
#
# "folks" - unigram
# "all folks" - bigram
# "all folks!" - trigram
#
# 4-grams, 5-grams, 6-grams

# %%
list(nltk.ngrams(porky_tokens, 3))
# Out:
# [('the', 'the', 'the'),
#  ('the', 'the', 'the'),
#  ('the', 'the', 'the'),
#  ('the', 'the', 'the'),
#  ('the', 'the', 'that'),
#  ('the', 'that', "'s"),
#  ('that', "'s", 'all'),
#  ("'s", 'all', 'folks'),
#  ('all', 'folks', '!')]

# %%
list(nltk.bigrams(porky_tokens))
# Out:
# [('the', 'the'),
#  ('the', 'the'),
#  ('the', 'the'),
#  ('the', 'the'),
#  ('the', 'the'),
#  ('the', 'that'),
#  ('that', "'s"),
#  ("'s", 'all'),
#  ('all', 'folks'),
#  ('folks', '!')]

# %%
frequent_bigrams = nltk.FreqDist(nltk.trigrams(text1))

# %%
frequent_bigrams
# Out:
# FreqDist({(',', 'and', 'the'): 187, ('don', "'", 't'): 103, ('of', 'the', 'whale'): 101, (',', 'in', 'the'): 93, (',', 'then', ','): 87, ('whale', "'", 's'): 81, ('.', 'It', 'was'): 81, ('ship', "'", 's'): 80, ('the', 'Sperm', 'Whale'): 77, (',', 'as', 'if'): 76, ...})

# %%
list(frequent_bigrams)[50:]
# Out:
# [('Whale', "'", 's'),
#  ('the', 'ship', ','),
#  (',', 'which', ','),
#  (',', 'and', 'I'),
#  ('I', 'say', ','),
#  (',', 'and', 'that'),
#  ('mast', '-', 'head'),
#  (',', 'like', 'a'),
#  ('it', ',', 'and'),
#  ('there', "'", 's'),
#  ('.', 'In', 'the'),
#  ('the', 'deck', ','),
#  (',', 'for', 'the'),
#  ("'", 's', 'head'),
#  (';', 'and', ','),
#  ('boat', "'", 's'),
#  ('the', 'whale', '-'),
#  (',"', 'said', 'I'),
#  ('I', 'don', "'"),
#  ('said', 'I', ','),
#  ('of', 'the', 'ship'),
#  (',', 'who', ','),
#  (',', 'and', 'so'),
#  (',', 'Mr', '.'),
#  ('mast', '-', 'heads'),
#  (';', 'and', 'so'),
#  ('.', 'But', ','),
#  (';', 'so', 'that'),
#  ('"', 'Aye', ','),
#  ('.', '"', 'The'),
#  ('It', "'", 's'),
#  (',', 'the', 'whale'),
#  ('in', 'the', 'sea'),
#  ('of', 'it', ','),
#  (',', 'and', 'all'),
#  (',', 'I', "'"),
#  ('of', 'the', 'Pequod'),
#  ('the', 'old', 'man'),
#  ('that', 'is', ','),
#  (',', 'as', 'it'),
#  (',', 'on', 'the'),
#  (',', 'indeed', ','),
# ...

# %%
import string

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
[word for word in text1 if word not in string.punctuation] # List comprehensions

moby_no_punct = []
for word in text1: 
    if word not in string.punctuation:
        moby_no_punct.append(word)

# %%
whales = text1.findall("<.*><whale>")
# Out:
# a whale; piggledy whale; ( whale; This whale; the whale; one whale; a
# whale; wounded whale; a whale; the whale; the whale; a whale; a whale;
# a whale; the whale; ceti whale; the whale; of whale; The whale; dead
# whale; the whale; great whale; are whale; a whale; a whale; the whale;
# The whale; mightier whale; a whale; a whale; a whale; the whale; one
# whale; the whale; the whale; that whale; a whale; The whale; the
# whale; the whale; a whale; the whale; great whale; the whale; the
# whale; American whale; exasperated whale; a whale; right whale; the
# whale; the whale; a whale; the whale; great whale; the whale; the
# whale; the whale; mighty whale; the whale; the whale; the whale; the
# whale; the whale; wandering whale; big whale; exasperated whale; sperm
# whale; - whale; a whale; a whale; particular whale; live whale; and
# whale; a whale; accursed whale; a whale; the whale; one whale; him
# whale; dad whale; good whale; a whale; t whale; sperm whale; a whale;
# ...

# %%
text1.findall('<whal.*>')
# Out:
# whale; whales; whale; whales; whales; whales; whale; whale; whale;
# whale; whale; whale; whales; whale; whales; whale; whales; whales;
# whale; whale; whale; whale; whales; whale; whale; whales; whale;
# whale; whale; whale; whale; whales; whale; whale; whale; whale; whale;
# whale; whale; whales; whale; whale; whales; whale; whale; whale;
# whale; whale; whale; whale; whale; whale; whale; whalemen; whale;
# whales; whales; whales; whale; whaling; whaling; whaling; whale;
# whale; whaling; whale; whaling; whaling; whale; whalemen; whales;
# whaling; whale; whaling; whales; whale; whale; whale; whalin; whale;
# whale; whaleman; whaleman; whalemen; whaling; whales; whalemen;
# whaling; whale; whale; whalemen; whales; whalemen; whaling; whalemen;
# whaling; whale; whale; whale; whale; whale; whale; whale; whale;
# whale; whaler; whaleman; whalemen; whaling; whaleman; whaling;
# whaling; whales; whale; whale; whale; whales; whaling; whalemen;
# ...

# %%
whaleCounter = []
for word in text1: 
    if word.startswith('whal'): 
        whaleCounter.append(word)

[word for word in text1 if word.startswith('whal')] # List comprehension
# Out:
# ['whale',
#  'whales',
#  'whale',
#  'whales',
#  'whales',
#  'whales',
#  'whale',
#  'whale',
#  'whale',
#  'whale',
#  'whale',
#  'whale',
#  'whales',
#  'whale',
#  'whales',
#  'whale',
#  'whales',
#  'whales',
#  'whale',
#  'whale',
#  'whale',
#  'whale',
#  'whales',
#  'whale',
#  'whale',
#  'whales',
#  'whale',
#  'whale',
#  'whale',
#  'whale',
#  'whale',
#  'whales',
#  'whale',
#  'whale',
#  'whale',
#  'whale',
#  'whale',
#  'whale',
#  'whale',
#  'whales',
#  'whale',
#  'whale',
#  'whales',
#  'whale',
#  'whale',
#  'whale',
#  'whale',
#  'whale',
#  'whale',
#  'whale',
#  'whale',
#  'whale',
#  'whale',
#  'whalemen',
#  'whale',
#  'whales',
#  'whales',
#  'whales',
#  'whale',
#  'whaling',
#  'whaling',
#  'whaling',
#  'whale',
#  'whale',
#  'whaling',
#  'whale',
#  'whaling',
#  'whaling',
#  'whale',
#  'whalemen',
#  'whales',
#  'whaling',
#  'whale',
#  'whaling',
#  'whales',
#  'whale',
#  'whale',
#  'whale',
#  'whalin',
# ...

# %%
nltk.FreqDist(whaleCounter)
# Out:
# FreqDist({'whale': 906, 'whales': 237, 'whaling': 116, 'whalemen': 71, 'whaleman': 44, 'whalers': 19, 'whaler': 16, 'whalebone': 8, 'whaleboats': 4, 'whalin': 1, ...})

# %%
# Out:
# "the the the the the the that's all folks!"

# %%
text1.generate()
# Out:
# Building ngram index...
# long , from one to the top - mast , and no coffin and went out a sea
# captain -- this peaking of the whales . , so as to preserve all his
# might had in former years abounding with them , they toil with their
# lances , strange tales of Southern whaling . at once the bravest
# Indians he was , after in vain strove to pierce the profundity . ?
# then ?" a levelled flame of pale , And give no chance , watch him ;
# though the line , it is to be gainsaid . have been
# 'long , from one to the top - mast , and no coffin and went out a sea\ncaptain -- this peaking of the whales . , so as to preserve all his\nmight had in former years abounding with them , they toil with their\nlances , strange tales of Southern whaling . at once the bravest\nIndians he was , after in vain strove to pierce the profundity . ?\nthen ?" a levelled flame of pale , And give no chance , watch him ;\nthough the line , it is to be gainsaid . have been'

# %%
text6.generate()
# Out:
# Building ngram index...
# Saint Aauuuves in Cornwall ? ' s all ! ARTHUR : How can we come up and
# have a plan , sir . rodent you ever set eyes on . Hello . Do they
# listen to me ! , great . Ninepence . who , when he seemed about to
# recover , suddenly felt the icy hand of death upon him . No SCENE 19 :
# ARTHUR : Walk away . squeak ] [ howl ] [ creak ] CROWD : Tell us ! -
# wom ! utterly disheartened King Arthur music stops ] BLACK KNIGHT ' s
# your next
# "Saint Aauuuves in Cornwall ? ' s all ! ARTHUR : How can we come up and\nhave a plan , sir . rodent you ever set eyes on . Hello . Do they\nlisten to me ! , great . Ninepence . who , when he seemed about to\nrecover , suddenly felt the icy hand of death upon him . No SCENE 19 :\nARTHUR : Walk away . squeak ] [ howl ] [ creak ] CROWD : Tell us ! -\nwom ! utterly disheartened King Arthur music stops ] BLACK KNIGHT ' s\nyour next"

# %%
text6.dispersion_plot(['ni', 'shrubbery'])

# %%
text1.dispersion_plot(['Ahab', 'whale'])

# %%
text4.dispersion_plot(['America', 'citizen'])

# %%
nltk.FreqDist(text6).hapaxes()
# Out:
# ['KING',
#  'Whoa',
#  'goes',
#  'Uther',
#  'Pendragon',
#  'defeator',
#  'Saxons',
#  'sovereign',
#  'trusty',
#  'length',
#  'breadth',
#  'Ridden',
#  'horse',
#  'using',
#  'halves',
#  'bangin',
#  'snows',
#  'Found',
#  'tropical',
#  'temperate',
#  'zone',
#  'fly',
#  'south',
#  'sun',
#  'house',
#  'martin',
#  'plover',
#  'warmer',
#  'climes',
#  'strangers',
#  'suggesting',
#  'migrate',
#  'carrying',
#  'grip',
#  'husk',
#  'grips',
#  'weight',
#  'ratios',
#  'ounce',
#  'bird',
#  'matter',
#  'maintain',
#  'needs',
#  'wings',
#  'forty',
#  'Am',
#  'interested',
#  'maybe',
#  'wants',
#  'non',
#  'migratory',
#  'couldn',
#  'bring',
#  'Supposing',
#  'strand',
#  'creeper',
#  'dorsal',
#  'guiding',
#  'feathers',
#  '[...',
#  'ninepence',
#  'Ere',
#  'ill',
#  'moment',
#  'regulations',
#  'cart',
#  'baby',
#  'hang',
#  'around',
#  'couple',
#  'Robinson',
#  'nine',
#  'walk',
#  'thanks',
#  'dunno',
#  'Must',
#  'hasn',
#  'looked',
# ...

# %%
text6.concordance('shrubbery', lines=100)
# Out:
# Displaying 13 of 13 matches:
# want ? HEAD KNIGHT : We want ... a shrubbery ! [ dramatic chord ] ARTHUR : A wh
# ase ! No more ! We will find you a shrubbery . HEAD KNIGHT : You must return he
# IGHT : You must return here with a shrubbery or else you will never pass throug
# d fair , and we will return with a shrubbery . HEAD KNIGHT : One that looks nic
#  in this town where we could buy a shrubbery ? [ dramatic chord ] OLD CRONE : W
#  do not tell us where we can buy a shrubbery , my friend and I will say ... we
# s of Ni , we have brought you your shrubbery . May we go now ? HEAD KNIGHT : It
# o now ? HEAD KNIGHT : It is a good shrubbery . I like the laurels particularly
# irstly , you must find ... another shrubbery ! [ dramatic chord ] ARTHUR : Not
# matic chord ] ARTHUR : Not another shrubbery ! RANDOM : Ni ! HEAD KNIGHT : Then
# T : Then , when you have found the shrubbery , you must place it here beside th
# ...

# %%
text6.collocations()
# Out:
# BLACK KNIGHT; clop clop; HEAD KNIGHT; mumble mumble; Holy Grail;
# squeak squeak; FRENCH GUARD; saw saw; Sir Robin; Run away; CARTOON
# CHARACTER; King Arthur; Iesu domine; Pie Iesu; DEAD PERSON; Round
# Table; clap clap; OLD MAN; dramatic chord; dona eis

# %%
text6.common_contexts(['knight'])
# Out:
# head_: black_: green_: black_' sir_. sir_, a_of what_live black_and
# black_kills green_] black_always ,_of --_: [_kills handsome_? a_to
# head_of influential_, valiant_shall

# %%
text1.common_contexts(['whale'])
# Out:
# the_, the_' the_- sperm_' the_. sperm_, a_- a_, the_is the_; white_,
# sperm_. white_' right_' the_was sperm_is right_, white_?" the_and
# the_in

# %%
nltk.Text()
